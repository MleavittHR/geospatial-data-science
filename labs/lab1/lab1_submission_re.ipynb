# %% [markdown]
# <h4>Task 1</h4>

# %%
import numpy as np
a = 5
b = 257
c = np.multiply(a, b)
print(c)
# Out:
# 1285

# %% [markdown]
# <h4>Task 2<h4>

# %% [markdown]
# ![a8zoxjtox5281.jpeg](attachment:a8zoxjtox5281.jpeg)
# Here is my link to [inspiringImage](https://www.google.com/search?q=meteora+greece&rlz=1C5CHFA_enUS761US762&sxsrf=AOaemvJwDSfEyD7-dJUeUmITsnd-PttgBQ:1641423755642&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi-qIX_25v1AhUODzQIHZvBCTgQ_AUoAXoECAIQAw&biw=1440&bih=789&dpr=1#imgrc=rmWYHNLGbVOI7M).
#
# The Summer after senior year I visited ***Meteora in Greece*** as a treat my self for graduating and getting accepted to U of O. The place is straight up *magical and surreal*
